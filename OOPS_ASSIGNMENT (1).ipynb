# %% [markdown]
# #Python OOPs Questions
#
#
#
#
# 1.  What is Object-Oriented Programming (OOP)?
#
#
#     -It is a way of programing and organizing code in a easy way to make it reusable and organised.
#
#     Benefits:
#
#  Code reusability
#
#  Easier maintenance
#
#  Improved modularity
#
#
#
# 2. What is a class in OOPs?
#
#
#    -A class in OOP is a blueprint for creating objects (a particular data structure), providing initial values for state (member variables or attributes), and implementations of behavior (member functions or methods).
#
#
# 3.  What is an object in OOP?
#
#    -An object in OOP is an instance of a class. It is a concrete entity created from the blueprint defined by the class.
#
#
# 4. What is the difference between abstraction and encapsulation?
#
#
#     -Abstraction: Focuses on hiding complex implementation details and showing only the essential features of an object. It's about "what" the object does, not "how" it does it.
# Encapsulation: Is the bundling of data (attributes) and methods (functions) that operate on the data into a single unit, a class. It's about restricting direct access to some of an object's components and preventing accidental modification.
#
#
#
# 5.  What are dunder methods in Python?
#
#     -Dunder methods in phython are the methods as the name itself suggests "dunder" a method which start and end with underscore also called magic or special method.
#
#
# 6.  Explain the concept of inheritance in OOP?
#
#      -Inheritance refers to a child inheriting properties of his parents similarly in phython inheritance refers to child class inheriting properties of parent class.
#
#
# 7.  What is polymorphism in OOP?
#
#
#        -Polymorphism refers to many forms in phython.
#
#
#
# 8.  How is encapsulation achieved in Python?
#
#
#        -In Python, encapsulation is achieved through the use of:
#
# Classes: Bundling data (attributes) and methods (functions) into a single unit.
# Access Modifiers (by convention): Python doesn't have strict keywords for private or protected members like some other languages (e.g., private, public, protected in Java). Instead, it uses naming conventions:
# Public: Attributes and methods are public by default (no leading underscores). They can be accessed from anywhere.
# Protected: Attributes and methods are prefixed with a single underscore (e.g., _my_attribute). This is a convention indicating that they should be treated as protected and are primarily for internal use within the class and its subclasses. However, they can still be accessed from outside the class.
# Private: Attributes and methods are prefixed with a double underscore (e.g., __my_attribute). This triggers name mangling, making them harder to access from outside the class directly. While not truly private (you can still access them using the mangled name), it's a stronger convention for indicating privacy.
# Colab.
#
#
#
#
# 9.  What is a constructor in Python?
#
#
#     -A constructor in Python is a special method called __init__ that is automatically called when you create a new object (an instance) of a class. Its primary purpose is to initialize the object's attributes (data).
#
#
# 10. What are class and static methods in Python?
#
#
#       - Class Methods: Bound to the class itself, they have access to the class's attributes.
#
#
#
#        -Static Methods: Not bound to the class or instance, they're essentially regular functions.
#
#
#
#
#
# 11.  What is method overloading in Python?
#
#
#
#      -Python doesn't support traditional method overloading like some other languages (e.g., Java or C++). However, you can achieve similar behavior using:
#
# . Default Argument Values: Provide default values for some arguments, making them optional.
#
#
#
# . Variable Argument Lists: Use *args or **kwargs to accept a variable number of arguments.
#
#
#
# . Single Dispatch: Use the @singledispatch decorator from the functools module to define a single function that can handle different types of arguments.
#
#
#
#
# 12.  What is method overriding in OOP?
#
#
#
#       -Method overriding is a feature of object-oriented programming (OOP) that allows a subclass to provide a different implementation of a method that's already defined in its superclass.
#
# Key Characteristics:
#
# . Same Method Name: The subclass method has the same name as the superclass method.
#
#
#
# . Same Method Signature: The subclass method has the same parameters as the superclass method.
#
#
#
# . Different Implementation: The subclass method provides a different implementation than the superclass method.
#
#
#
#
# 13.  What is a property decorator in Python?
#
#
#
#
#     -The @property decorator in Python allows you to customize access to instance attributes. It enables you to define getter, setter, and deleter methods for an attribute, making it possible to:
#
#  Control access: Validate or transform values before setting an attribute.
#
#
#
#
#  Implement lazy loading: Compute attribute values on demand.
#
#
#
#
#
#
#
#  Provide read-only access: Prevent modification of an attribute.
#
#
#
#
#
#
#
#  14.   Why is polymorphism important in OOP?
#
#
#
#
#
#      -Polymorphism is a fundamental concept in object-oriented programming (OOP) that allows objects of different classes to be treated as objects of a common superclass. This enables:
#
# . Flexibility: Write code that works with different types of objects.
#
#
#
#
# . Modularity: Break down complex systems into smaller, independent components.
#
#
#
#
#
#
# . Reusability: Use the same code with different types of objects.
#
#
#
#
#
#
# 15.   What is an abstract class in Python?
#
#
#
#
#
#          -An abstract class in Python is a class that can't be instantiated on its own and is designed to be inherited by other classes.
#
#
#
#
#
#
# 16.  What are the advantages of OOP?
#
#
#
#
#
#       -  . Modularity: Break down complex systems into smaller, independent modules (classes) that are easier to manage and maintain.
#
#
#
#
#       .Write code that can be reused in multiple contexts, reducing duplication and improving efficiency.
#
#
#
#
#
#
#       .Create a hierarchy of classes that inherit properties and behavior from parent classes, promoting code reuse and facilitating the creation of specialized classes.
#
#
#
#
#
#
#
#
# 17.  What is the difference between a class variable and an instance variable?
#
#
#
#
#
#         -
#         Class Variables:
#     - Shared by all instances of the class.
#     - Defined at the class level.
#     - Used for data that's common to all instances.
#
#
#
#
#
#
#  Instance Variables:
#     - Unique to each instance of the class.
#     - Defined inside methods (usually __init__).
#     - Used for data that's specific to each instance.
#
#
#
#
#
# 18. What is multiple inheritance in Python?
#
#
#
#
#        -Multiple inheritance is a feature in Python that allows a class to inherit properties and behavior from more than one parent class.
#
#
#
#
#
#        .it enables .....
#
#
#
#        *combined behaviour
#
#
#
#
#        *increased flexibility
#
#
#
#
#
#
#
#
#
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
#
#
#
#
#
#         - *__str__*:
#     - Returns a human-readable string representation of the object.
#     - Intended for end-users, logging, or display purposes.
#     - Should be concise and informative.
#
#
#
#
#
# *__repr__*:
#     - Returns a string representation of the object that's useful for debugging and development.
#     - Ideally, it should be a valid Python expression that could recreate the object.
#     - Intended for developers, logging, or debugging purposes.
#
#
#
#
#
# 20.  What is the significance of the ‘super()’ function in Python?
#
#
#
#
#
#        -the super() function in Python is used to access methods and properties of a parent class (also known as a superclass) from a child class. It allows you to:
#
# . Override methods: Call the parent class's method from the child class, even if the child class overrides it.
#
#
#
#
#
#
# . Extend behavior: Add new behavior to a parent class's method while still calling the original method.
#
#
#
#
#
#
#
#
#
# 21. What is the significance of the __del__ method in Python?
#
#
#
#
#
#
#         -The __del__ method in Python is a special method that's called when an object is about to be destroyed. It's also known as a finalizer or destructor. The __del__ method is used to:
#
#
#
#
#         release resouses
#
#
#
#
#
#
#
#
#         cleanup
#
#
#
#
#
# 22.  What is the difference between @staticmethod and @classmethod in Python?
#
#
#
#
#          -@staticmethod*:
#     - Doesn't take any implicit arguments (neither self nor cls).
#     - Can't access or modify class or instance attributes.
#     - Used for utility functions that belong to the class's namespace.
#  *@classmethod*:
#     - Takes the class as the first argument (cls).
#     - Can access or modify class attributes.
#     - Used for alternative constructors, class-level operations, or inheritance.
#
#
#
#
# 23.   How does polymorphism work in Python with inheritance?
#
#
#
#
#         -Polymorphism is the ability of an object to take on multiple forms. In Python, polymorphism can be achieved through inheritance, where a subclass inherits the properties and behavior of a parent class and can also add new behavior or override existing behavior.
#
#
#
#
#
#
#
#
# 24.    What is method chaining in Python OOP?
#
#
#
#
#          -Method chaining is a technique in Python where multiple methods are called on the same object in a single statement. Each method returns the object itself, allowing the next method to be called on the same object.
#
#
#
#
#
#
# 25.   What is the purpose of the __call__ method in Python?
#
#
#
#         -The __call__ method in Python is a special method that allows an instance of a class to be called as a function. It enables objects to behave like functions, making them more flexible and reusable.

# %% [markdown]
# #PRACTICAL QUESTIONS

# %%
#1  Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".




class Animal:
    def speak(self):
        print("The animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")


animal = Animal()
dog = Dog()

animal.speak()
dog.speak()
# Out:
# The animal makes a sound.
# Bark!

# %%
#2  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.





class Shape(ABC):
         @abstractmethod
        def area(self):
        pass

# Derived class Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

# Derived class Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
# Out:
#   File "<tokenize>", line 10
#     def area(self):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#3  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.




class vehicle:
  def  vehicle_type(self):
   print("This is my vehicle.")

class Electric_car:
  def electric_car(self):
    print("This is my electric car.")





car=vehicle()
ec=Electric_car()


car.vehicle_type()
ec.electric_car()
# Out:
# This is my vehicle.
# This is my electric car.

# %%
#4 Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.





class bird:
   def fly():
     print("Bird can fly")

class Sparrow:
   def fly_s():
    print("Sparrow can fly")

class Penguin:
   def fly_p():
    print("Penguin can't fly")

# %%
#5 . Write a program to demonstrate encapsulation by creating a class BankAccount with private attributesbalance and methods to deposit, withdraw, and check balance.





class BankAccount:
    def __init__(self, balance=0):
        # Private attribute using double underscore convention
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}. New balance: ${self.__balance}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount > 0:
            if self.__balance >= amount:
                self.__balance -= amount
                print(f"Withdrew: ${amount}. New balance: ${self.__balance}")
            else:
                print("Insufficient funds.")
        else:
            print("Withdrawal amount must be positive.")

    def check_balance(self):
        print(f"Current balance: ${self.__balance}")

# Demonstrate encapsulation
account = BankAccount(100)
account.check_balance()
account.deposit(50)
account.withdraw(20)
account.check_balance()
account.withdraw(200)
# Out:
# Current balance: $100
# Deposited: $50. New balance: $150
# Withdrew: $20. New balance: $130
# Current balance: $130
# Insufficient funds.

# %%
#6.Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().




class Instrument:
    def play(self):
        print("Playing an instrument")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar")

class Piano(Instrument):
    def play(self):
        print("Playing the piano keys")

# Demonstrate runtime polymorphism
def make_instrument_play(instrument):
    instrument.play()

instrument1 = Instrument()
guitar = Guitar()
piano = Piano()

make_instrument_play(instrument1)
make_instrument_play(guitar)
make_instrument_play(piano)
# Out:
# Playing an instrument
# Strumming the guitar
# Playing the piano keys

# %%
#7.  Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.





class MathOperations:
    @classmethod
    def add_numbers(cls, num1, num2):
        return num1 + num2

    @staticmethod
    def subtract_numbers(num1, num2):
        return num1 - num2

# %%
#8.  Implement a class Person with a class method to count the total number of persons created.







class Person:
    total_persons = 0

    def __init__(self, name, age):
        self.name = name
        self.age = age
        Person.total_persons += 1

    @classmethod
    def count_persons(cls):
        return cls.total_persons

# Create some Person instances
person1 = Person("John", 30)
person2 = Person("Alice", 25)
person3 = Person("Bob", 40)

# Get the total number of persons
total_persons = Person.count_persons()
print(f"Total persons: {total_persons}")
# Out:
# Total persons: 3

# %%
#9.Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
#10.Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.




class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# Create two Vector instances
v1 = Vector(2, 3)
v2 = Vector(4, 5)

# Add the vectors using the + operator
v3 = v1 + v2

print(f"v1: {v1}")
print(f"v2: {v2}")
print(f"v1 + v2: {v3}")
# Out:
# v1: (2, 3)
# v2: (4, 5)
# v1 + v2: (6, 8)

# %%
#11.  Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is{name} and I am {age} years old".


class Person:
    def __init__(self, name, age):



           self.name = "Soha"
           self.age = 18

           print(" Hello, my name is{name} and I am {age} years old")

# %%
#12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.





class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

# %%
#13.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.




class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        if length <= 0 or width <= 0:
            raise ValueError("Length and width must be positive")
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width




angle=Rectangle()
angle.set_dimensions(5,4)
angle.area()
# Out:
# 20

# %%
#14.  Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.


class Employee:
    def __init__(self, name, hourly_rate):
        self.name = name
        self.hourly_rate = hourly_rate
        self.hours_worked = 0

    def calculate_salary(self):
        return self.hourly_rate * self.hours_worked

    def set_hours_worked(self, hours):
        if hours < 0:
            raise ValueError("Hours worked cannot be negative")
        self.hours_worked = hours

class Manager(Employee):
    def __init__(self, name, hourly_rate, bonus):
        super().__init__(name, hourly_rate)
        self.bonus = bonus


# Create an Employee instance
employee = Employee("John", 50)
employee.set_hours_worked(40)
print(f"Employee salary: ${employee.calculate_salary():.2f}")

# Create a Manager instance
manager = Manager("Jane", 75, 1000)
manager.set_hours_worked(40)
print(f"Manager salary: ${manager.calculate_salary():.2f}")
# Out:
# Employee salary: $2000.00
# Manager salary: $3000.00

# %%
#15. . Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.



class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


print(Product)
# Out:
# <class '__main__.Product'>

# %%
#16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.




from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo!"

class Sheep(Animal):
    def sound(self):
        return "Baa!"

# Create instances
cow = Cow()
sheep = Sheep()

# Make sounds
print(f"Cow says: {cow.sound()}")
print(f"Sheep says: {sheep.sound()}")
# Out:
# Cow says: Moo!
# Sheep says: Baa!

# %%
#17.Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.


class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

        def get_book_info(self):
         return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# %%
#18.  Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.



class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)

        self.number_of_rooms = number_of_rooms
        number_of_rooms=19
        print(number_of_rooms)
